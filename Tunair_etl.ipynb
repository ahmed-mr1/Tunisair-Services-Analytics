# %% [markdown]
# # Tunisair ETL — Project Overview
#
# This notebook builds a simple, reproducible ETL pipeline for Tunisair flights using the Aviationstack API.
#
# - Purpose: Extract flight records for airline IATA `TU`, then clean and export a ready‑to‑analyze dataset.
# - Key steps:
#   1) Extract: Call API and save raw JSON to auto‑incremented files (`raw_tunisair_flights.json`, `raw_tunisair_flights2.json`, ...).
#   2) Combine: Merge all `raw_tunisair_flights*.json` into a single `raw_tunisair_flights_combined.json`.
#   3) Dedupe: Remove exact duplicate records and save `raw_tunisair_flights_combined_dedup.json` (+ CSV).
#   4) Transform: Normalize, clean, enrich, and summarize.
#   5) Load: Export the final clean CSV `clean_tunisair_flights.csv`.

# %% [markdown]
# ## Quickstart
#
# - Requirements: Python 3.9+ and packages: `pandas`, `numpy`, `requests`.
# - API key: Update the `API_KEY` value in the extract cell (Aviation Stack API Key).
# - Run order:
#   1) Libraries import
#   2) Extract (auto‑incremented output file)
#   3) 1.2 Combine Raw Files
#   4) 1.3 Remove Duplicates
#   5) Load Raw JSON Data → Transform → Load (CSV)
#
# Outputs
# - Raw: `raw_tunisair_flights*.json`
# - Combined: `raw_tunisair_flights_combined.json`
# - Deduped: `raw_tunisair_flights_combined_dedup.json`
# - Clean: `clean_tunisair_flights.csv`

# %% [markdown]
# ## 1. Extract Raw JSON Data

# %% [markdown]
# 1.1. Importing required packages

# %%
import json
import pandas as pd
import numpy as np
from datetime import datetime
import requests
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully!")
print(f"Pandas version: {pd.__version__}")
# Out:
# Libraries imported successfully!
# Pandas version: 2.3.3

# %% [markdown]
# Due to API limitations, this code extracts 100 flights. We will run it several times to ensure we get enough data for analyzing and visualizing.

# %%
API_KEY = "f9a3ebd329fea81d036463417e0b6ce9"

url = "http://api.aviationstack.com/v1/flights"
params = {
    "access_key": API_KEY,
    "airline_iata": "TU",
    "limit": 100
}

response = requests.get(url, params=params)

data = response.json()

# Save raw JSON data to the next available filename
import os
import re
import glob

def next_available_filename(base="data/json/raw_tunisair_flights", ext=".json"):
    os.makedirs(os.path.dirname(base), exist_ok=True)
    files = glob.glob(f"{base}*{ext}")
    used = set()
    for fn in files:
        bn = os.path.basename(fn)
        base_name = os.path.basename(base)
        if bn == f"{base_name}{ext}":
            used.add(1)
        else:
            m = re.match(rf"^{re.escape(base_name)}(\d+){re.escape(ext)}$", bn)
            if m:
                used.add(int(m.group(1)))
    if not used:
        return f"{base}{ext}"
    n = 2 if 1 in used else 1
    while n in used:
        n += 1
    return f"{base}{n}{ext}"

output_file = next_available_filename()
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2, ensure_ascii=False)

print(f"JSON data saved to {output_file}")
print("Records extracted:", len(data.get("data", [])))
# Out:
# JSON data saved to data/json/raw_tunisair_flights21.json
# Records extracted: 100

# %% [markdown]
# ### 1.2 Combine Raw Files
# Combine all `raw_tunisair_flights*.json` files (only their `data` arrays) into a single file `raw_tunisair_flights_combined.json`. This ignores API `pagination` metadata.

# %%
# Combine all raw JSON files into one combined file
import json
import glob

input_files = sorted(glob.glob("data/json/raw_tunisair_flights*.json"))
combined_records = []
files_used = 0

for path in input_files:
    try:
        with open(path, "r", encoding="utf-8") as f:
            payload = json.load(f)
            records = payload.get("data", [])
            if records:
                combined_records.extend(records)
                files_used += 1
    except Exception as e:
        print(f"Skipping {path}: {e}")

combined_output = "data/json/raw_tunisair_flights_combined.json"
with open(combined_output, "w", encoding="utf-8") as f:
    json.dump({"data": combined_records}, f, indent=2, ensure_ascii=False)

print(f"Combined {files_used} files -> {combined_output}")
print(f"Total records combined: {len(combined_records)}")
# Out:
# Combined 23 files -> data/json/raw_tunisair_flights_combined.json
# Total records combined: 29677

# %% [markdown]
# ### 1.3 Remove Duplicates
# Remove exact-duplicate flight records from `raw_tunisair_flights_combined.json` and save to `raw_tunisair_flights_combined_dedup.json`

# %%
# Remove exact duplicates from the combined file and export JSON + CSV
import json
import pandas as pd
import os

combined_input = "data/json/raw_tunisair_flights_combined.json"
dedup_output_json = "data/json/raw_tunisair_flights_combined_dedup.json"
dedup_output_csv = "data/csv/raw_tunisair_flights_combined_dedup.csv"

os.makedirs("data/csv", exist_ok=True)

with open(combined_input, "r", encoding="utf-8") as f:
    payload = json.load(f)

records = payload.get("data", [])

seen = set()
deduped = []
for rec in records:
    # Hash the entire record to identify exact duplicates
    key = json.dumps(rec, sort_keys=True, ensure_ascii=False)
    if key not in seen:
        seen.add(key)
        deduped.append(rec)

with open(dedup_output_json, "w", encoding="utf-8") as f:
    json.dump({"data": deduped}, f, indent=2, ensure_ascii=False)

print(f"Removed duplicates: {len(records) - len(deduped)}")
print(f"Deduped total records: {len(deduped)}")
print(f"Saved JSON -> {dedup_output_json}")
# Out:
# Removed duplicates: 28734
# Deduped total records: 943
# Saved JSON -> data/json/raw_tunisair_flights_combined_dedup.json

# %% [markdown]
# ## 2. Load Raw JSON Data

# %%
# Load raw JSON data
with open('data/json/raw_tunisair_flights_combined_dedup.json', 'r') as f:
    raw_data = json.load(f)

print(f"\nTotal flights extracted: {len(raw_data['data'])}")
# Out:
# Total flights extracted: 943

# %%
# Explore the structure of one flight record
if raw_data['data']:
    sample_flight = raw_data['data'][0]
    print("Sample Flight Record Structure:")
    print(json.dumps(sample_flight, indent=2))
# Out:
# Sample Flight Record Structure:
# {
#   "flight_date": "2025-12-23",
#   "flight_status": "scheduled",
#   "departure": {
#     "airport": "Carthage",
#     "timezone": "Africa/Tunis",
#     "iata": "TUN",
#     "icao": "DTTA",
#     "terminal": "M",
#     "gate": null,
#     "delay": null,
#     "scheduled": "2025-12-23T20:05:00+00:00",
#     "estimated": "2025-12-23T20:05:00+00:00",
#     "actual": null,
#     "estimated_runway": null,
#     "actual_runway": null
#   },
#   "arrival": {
#     "airport": "King Abdulaziz International",
#     "timezone": "Asia/Riyadh",
#     "iata": "JED",
#     "icao": "OEJN",
#     "terminal": "N",
#     "gate": null,
#     "baggage": null,
#     "scheduled": "2025-12-24T02:30:00+00:00",
#     "delay": null,
#     "estimated": null,
#     "actual": null,
#     "estimated_runway": null,
#     "actual_runway": null
#   },
#   "airline": {
#     "name": "Tunisair",
#     "iata": "TU",
#     "icao": "TAR"
#   },
#   "flight": {
#     "number": "913",
#     "iata": "TU913",
#     "icao": "TAR913",
#     "codeshared": null
#   },
#   "aircraft": null,
#   "live": null
# }

# %% [markdown]
# ## 3. Transform - Normalize and Clean Data

# %%
# Normalize nested JSON into flat DataFrame
df_raw = pd.json_normalize(raw_data['data'])

print(f"Raw DataFrame Shape: {df_raw.shape}")
print(f"\nColumn Names ({len(df_raw.columns)} columns):")
print(df_raw.columns.tolist())
# Out:
# Raw DataFrame Shape: (943, 54)
#
# Column Names (54 columns):
# ['flight_date', 'flight_status', 'aircraft', 'live', 'departure.airport', 'departure.timezone', 'departure.iata', 'departure.icao', 'departure.terminal', 'departure.gate', 'departure.delay', 'departure.scheduled', 'departure.estimated', 'departure.actual', 'departure.estimated_runway', 'departure.actual_runway', 'arrival.airport', 'arrival.timezone', 'arrival.iata', 'arrival.icao', 'arrival.terminal', 'arrival.gate', 'arrival.baggage', 'arrival.scheduled', 'arrival.delay', 'arrival.estimated', 'arrival.actual', 'arrival.estimated_runway', 'arrival.actual_runway', 'airline.name', 'airline.iata', 'airline.icao', 'flight.number', 'flight.iata', 'flight.icao', 'flight.codeshared', 'aircraft.registration', 'aircraft.iata', 'aircraft.icao', 'aircraft.icao24', 'flight.codeshared.airline_name', 'flight.codeshared.airline_iata', 'flight.codeshared.airline_icao', 'flight.codeshared.flight_number', 'flight.codeshared.flight_iata', 'flight.codeshared.flight_icao', 'live.updated', 'live.latitude', 'live.longitude', 'live.altitude', 'live.direction', 'live.speed_horizontal', 'live.speed_vertical', 'live.is_ground']

# %%
# Display first few rows
df_raw.head()
# Out:
#   flight_date flight_status  aircraft  live departure.airport  \
# 0  2025-12-23     scheduled       NaN   NaN          Carthage
# 1  2025-12-23     scheduled       NaN   NaN              Orly
# 2  2025-12-23     scheduled       NaN   NaN          Carthage
# 3  2025-12-23     scheduled       NaN   NaN          Heathrow
# 4  2025-12-23     scheduled       NaN   NaN              Orly
#
#   departure.timezone departure.iata departure.icao departure.terminal  \
# 0       Africa/Tunis            TUN           DTTA                  M
# 1       Europe/Paris            ORY           LFPO                  4
# 2       Africa/Tunis            TUN           DTTA                  M
# 3      Europe/London            LHR           EGLL                  4
# 4       Europe/Paris            ORY           LFPO               None
#
#   departure.gate  ...  flight.codeshared.flight_iata  \
# 0           None  ...                            NaN
# 1           None  ...                            NaN
# 2           None  ...                            NaN
# 3              D  ...                            NaN
# 4           None  ...                            NaN
#
#   flight.codeshared.flight_icao live.updated live.latitude live.longitude  \
# 0                           NaN          NaN           NaN            NaN
# 1                           NaN          NaN           NaN            NaN
# 2                           NaN          NaN           NaN            NaN
# 3                           NaN          NaN           NaN            NaN
# 4                           NaN          NaN           NaN            NaN
#
#   live.altitude live.direction live.speed_horizontal live.speed_vertical  \
# 0           NaN            NaN                   NaN                 NaN
# 1           NaN            NaN                   NaN                 NaN
# 2           NaN            NaN                   NaN                 NaN
# 3           NaN            NaN                   NaN                 NaN
# 4           NaN            NaN                   NaN                 NaN
#
#   live.is_ground
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 54 columns]

# %%
# Check data types and missing values
print("Data Info:")
df_raw.info()
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 54 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   flight_date                      943 non-null    object
#  1   flight_status                    854 non-null    object
#  2   aircraft                         0 non-null      float64
#  3   live                             0 non-null      float64
#  4   departure.airport                943 non-null    object
#  5   departure.timezone               937 non-null    object
#  6   departure.iata                   943 non-null    object
#  7   departure.icao                   943 non-null    object
#  8   departure.terminal               741 non-null    object
#  9   departure.gate                   131 non-null    object
#  10  departure.delay                  370 non-null    float64
#  11  departure.scheduled              943 non-null    object
#  12  departure.estimated              943 non-null    object
#  13  departure.actual                 523 non-null    object
#  14  departure.estimated_runway       523 non-null    object
#  15  departure.actual_runway          523 non-null    object
#  16  arrival.airport                  943 non-null    object
#  17  arrival.timezone                 937 non-null    object
#  18  arrival.iata                     943 non-null    object
#  19  arrival.icao                     943 non-null    object
#  20  arrival.terminal                 803 non-null    object
#  21  arrival.gate                     29 non-null     object
#  22  arrival.baggage                  94 non-null     object
#  23  arrival.scheduled                943 non-null    object
#  24  arrival.delay                    548 non-null    float64
#  25  arrival.estimated                517 non-null    object
#  26  arrival.actual                   242 non-null    object
#  27  arrival.estimated_runway         242 non-null    object
#  28  arrival.actual_runway            242 non-null    object
#  29  airline.name                     943 non-null    object
#  30  airline.iata                     943 non-null    object
#  31  airline.icao                     943 non-null    object
#  32  flight.number                    943 non-null    object
#  33  flight.iata                      943 non-null    object
#  34  flight.icao                      943 non-null    object
#  35  flight.codeshared                0 non-null      float64
#  36  aircraft.registration            60 non-null     object
#  37  aircraft.iata                    60 non-null     object
#  38  aircraft.icao                    60 non-null     object
#  39  aircraft.icao24                  781 non-null    object
#  40  flight.codeshared.airline_name   55 non-null     object
#  41  flight.codeshared.airline_iata   55 non-null     object
#  42  flight.codeshared.airline_icao   55 non-null     object
#  43  flight.codeshared.flight_number  55 non-null     object
#  44  flight.codeshared.flight_iata    55 non-null     object
#  45  flight.codeshared.flight_icao    55 non-null     object
#  46  live.updated                     60 non-null     object
#  47  live.latitude                    60 non-null     float64
#  48  live.longitude                   60 non-null     float64
#  49  live.altitude                    60 non-null     float64
#  50  live.direction                   60 non-null     float64
#  51  live.speed_horizontal            60 non-null     float64
#  52  live.speed_vertical              60 non-null     float64
#  53  live.is_ground                   60 non-null     object
# dtypes: float64(11), object(43)
# memory usage: 398.0+ KB

# %%
# Missing values analysis
missing_data = pd.DataFrame({
    'Column': df_raw.columns,
    'Missing_Count': df_raw.isnull().sum(),
    'Missing_Percentage': (df_raw.isnull().sum() / len(df_raw) * 100).round(2)
}).sort_values('Missing_Count', ascending=False)

print("\nMissing Values Analysis:")
print(missing_data[missing_data['Missing_Count'] > 0])
# Out:
# Missing Values Analysis:
#                                                           Column  \
# live                                                        live
# aircraft                                                aircraft
# flight.codeshared                              flight.codeshared
# arrival.gate                                        arrival.gate
# flight.codeshared.flight_number  flight.codeshared.flight_number
# flight.codeshared.flight_icao      flight.codeshared.flight_icao
# flight.codeshared.flight_iata      flight.codeshared.flight_iata
# flight.codeshared.airline_name    flight.codeshared.airline_name
# flight.codeshared.airline_iata    flight.codeshared.airline_iata
# flight.codeshared.airline_icao    flight.codeshared.airline_icao
# live.direction                                    live.direction
# aircraft.iata                                      aircraft.iata
# aircraft.icao                                      aircraft.icao
# live.updated                                        live.updated
# aircraft.registration                      aircraft.registration
# live.latitude                                      live.latitude
# live.longitude                                    live.longitude
# live.altitude                                      live.altitude
# live.speed_vertical                          live.speed_vertical
# live.is_ground                                    live.is_ground
# live.speed_horizontal                      live.speed_horizontal
# arrival.baggage                                  arrival.baggage
# departure.gate                                    departure.gate
# arrival.actual                                    arrival.actual
# arrival.actual_runway                      arrival.actual_runway
# arrival.estimated_runway                arrival.estimated_runway
# departure.delay                                  departure.delay
# arrival.estimated                              arrival.estimated
# departure.actual                                departure.actual
# departure.estimated_runway            departure.estimated_runway
# departure.actual_runway                  departure.actual_runway
# arrival.delay                                      arrival.delay
# departure.terminal                            departure.terminal
# aircraft.icao24                                  aircraft.icao24
# arrival.terminal                                arrival.terminal
# flight_status                                      flight_status
# arrival.timezone                                arrival.timezone
# departure.timezone                            departure.timezone
#
#                                  Missing_Count  Missing_Percentage
# live                                       943              100.00
# aircraft                                   943              100.00
# flight.codeshared                          943              100.00
# arrival.gate                               914               96.92
# flight.codeshared.flight_number            888               94.17
# flight.codeshared.flight_icao              888               94.17
# flight.codeshared.flight_iata              888               94.17
# flight.codeshared.airline_name             888               94.17
# flight.codeshared.airline_iata             888               94.17
# flight.codeshared.airline_icao             888               94.17
# live.direction                             883               93.64
# aircraft.iata                              883               93.64
# aircraft.icao                              883               93.64
# live.updated                               883               93.64
# aircraft.registration                      883               93.64
# live.latitude                              883               93.64
# live.longitude                             883               93.64
# live.altitude                              883               93.64
# live.speed_vertical                        883               93.64
# live.is_ground                             883               93.64
# live.speed_horizontal                      883               93.64
# arrival.baggage                            849               90.03
# departure.gate                             812               86.11
# arrival.actual                             701               74.34
# arrival.actual_runway                      701               74.34
# arrival.estimated_runway                   701               74.34
# departure.delay                            573               60.76
# arrival.estimated                          426               45.17
# departure.actual                           420               44.54
# departure.estimated_runway                 420               44.54
# departure.actual_runway                    420               44.54
# arrival.delay                              395               41.89
# departure.terminal                         202               21.42
# aircraft.icao24                            162               17.18
# arrival.terminal                           140               14.85
# flight_status                               89                9.44
# arrival.timezone                             6                0.64
# departure.timezone                           6                0.64

# %% [markdown]
# ### Selecting relevant columns

# %%
# Select important columns for analysis
columns_to_keep = [
    'flight_date',
    'flight_status',
    'departure.airport',
    'departure.iata',
    'departure.delay',
    'departure.scheduled',
    'departure.estimated',
    'departure.actual',
    'arrival.airport',
    'arrival.iata',
    'arrival.scheduled',
    'arrival.delay',
    'arrival.estimated',
    'arrival.actual',
    'airline.name',
    'airline.iata',
    'airline.icao',
    'flight.number',
    'flight.iata',
    'flight.icao',
]

# Keep only columns that exist in the dataframe
available_columns = [col for col in columns_to_keep if col in df_raw.columns]
df_clean = df_raw[available_columns].copy()

print(f"Selected {len(available_columns)} columns for cleaning")
print(f"Cleaned DataFrame Shape: {df_clean.shape}")
# Out:
# Selected 20 columns for cleaning
# Cleaned DataFrame Shape: (943, 20)

# %% [markdown]
# ## Renaming columns

# %%
# Rename columns with clearer names
column_mapping = {
    'flight_date':'flight_date',
    'flight_status':'flight_status',
    'departure.airport': 'departure_airport',
    'departure.timezone':'departure_timezone',
    'departure.iata':'departure_iata',
    'departure.delay':'departure_delay_minutes',
    'departure.scheduled':'departure_scheduled',
    'departure.estimated':'departure_estimated',
    'departure.actual':'departure_actual',
    'arrival.airport': 'arrival_airport',
    'arrival.timezone': 'arrival_timezone',
    'arrival.iata': 'arrival_iata',
    'arrival.scheduled': 'arrival_scheduled',
    'arrival.delay': 'arrival_delay_minutes',
    'arrival.estimated': 'arrival_estimated',
    'arrival.actual': 'arrival_actual',
    'airline.name': 'airline_name',
    'airline.iata': 'airline_iata',
    'airline.icao': 'airline_icao',
    'flight.number': 'flight_number',
    'flight.iata': 'flight_iata',
    'flight.icao': 'flight_icao',
}

df_clean.rename(columns=column_mapping, inplace=True)
print("Columns renamed successfully!")
print(f"\nNew column names:")
print(df_clean.columns.tolist())
# Out:
# Columns renamed successfully!
#
# New column names:
# ['flight_date', 'flight_status', 'departure_airport', 'departure_iata', 'departure_delay_minutes', 'departure_scheduled', 'departure_estimated', 'departure_actual', 'arrival_airport', 'arrival_iata', 'arrival_scheduled', 'arrival_delay_minutes', 'arrival_estimated', 'arrival_actual', 'airline_name', 'airline_iata', 'airline_icao', 'flight_number', 'flight_iata', 'flight_icao']

# %% [markdown]
# ### 3.3 Convert Date/Time Columns

# %%
# Convert datetime columns
datetime_columns = [
    'departure_scheduled', 'departure_estimated', 'departure_actual',
    'arrival_scheduled', 'arrival_estimated', 'arrival_actual'
]

for col in datetime_columns:
    if col in df_clean.columns:
        df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')

print("Datetime columns converted successfully!")
# Out:
# Datetime columns converted successfully!

# %% [markdown]
# ### 3.4 Clean and Convert Numeric Columns

# %%
# Convert numeric columns
numeric_columns = [
    'departure_delay_minutes', 'arrival_delay_minutes',
]

for col in numeric_columns:
    if col in df_clean.columns:
        df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')

print("Numeric columns converted successfully!")
# Out:
# Numeric columns converted successfully!

# %% [markdown]
# ### 3.5 Handle Missing Values

# %%
# Fill numeric delays with 0 if missing
if 'departure_delay_minutes' in df_clean.columns:
    df_clean['departure_delay_minutes'].fillna(0, inplace=True)

if 'arrival_delay_minutes' in df_clean.columns:
    df_clean['arrival_delay_minutes'].fillna(0, inplace=True)

# Fill categorical columns with "Unknown"
categorical_cols = df_clean.select_dtypes(include=['object', 'category']).columns
df_clean[categorical_cols] = df_clean[categorical_cols].fillna("Unknown")

print("Missing values handled!")
print(f"\nRemaining missing values:")
print(df_clean.isnull().sum().sum())
# Out:
# Missing values handled!
#
# Remaining missing values:
# 1547

# %% [markdown]
# ### 3.6 Add Derived Columns

# %%
# Add helpful derived columns

# Extract date components from flight_date
if 'flight_date' in df_clean.columns:
    df_clean['flight_date'] = pd.to_datetime(df_clean['flight_date'])
    df_clean['year'] = df_clean['flight_date'].dt.year
    df_clean['month'] = df_clean['flight_date'].dt.month
    df_clean['day'] = df_clean['flight_date'].dt.day
    df_clean['day_of_week'] = df_clean['flight_date'].dt.day_name()

# Calculate total delay (if both departure and arrival delays exist)
if 'departure_delay_minutes' in df_clean.columns and 'arrival_delay_minutes' in df_clean.columns:
    df_clean['total_delay_minutes'] = df_clean['departure_delay_minutes'] + df_clean['arrival_delay_minutes']

# Create a route identifier
if 'departure_iata' in df_clean.columns and 'arrival_iata' in df_clean.columns:
    df_clean['route'] = df_clean['departure_iata'].astype(str) + ' → ' + df_clean['arrival_iata'].astype(str)

# Flight is delayed flag
if 'total_delay_minutes' in df_clean.columns:
    df_clean['is_delayed'] = df_clean['total_delay_minutes'] > 15

print("Derived columns added successfully!")
print(f"\nFinal DataFrame Shape: {df_clean.shape}")
# Out:
# Derived columns added successfully!
#
# Final DataFrame Shape: (943, 27)

# %% [markdown]
# ## 4. Data Quality Summary

# %%
# Display cleaned data summary
print("="*60)
print("CLEANED DATA SUMMARY")
print("="*60)
print(f"\nTotal Records: {len(df_clean)}")
print(f"Total Columns: {len(df_clean.columns)}")
print(f"\nMemory Usage: {df_clean.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
print(f"\nData Types:")
print(df_clean.dtypes.value_counts())
# Out:
# ============================================================
# CLEANED DATA SUMMARY
# ============================================================
#
# Total Records: 943
# Total Columns: 27
#
# Memory Usage: 0.75 MB
#
# Data Types:
# object                 13
# datetime64[ns, UTC]     6
# int32                   3
# float64                 3
# datetime64[ns]          1
# bool                    1
# Name: count, dtype: int64

# %%
# Display statistical summary for numeric columns
print("\nNumeric Columns Summary:")
df_clean.describe()
# Out:
# Numeric Columns Summary:
#                          flight_date  departure_delay_minutes  \
# count                            943               943.000000
# mean   2025-12-25 07:45:44.856839936                22.974549
# min              2025-12-21 00:00:00                 0.000000
# 25%              2025-12-23 00:00:00                 0.000000
# 50%              2025-12-26 00:00:00                 0.000000
# 75%              2025-12-28 00:00:00                28.500000
# max              2025-12-30 00:00:00               270.000000
# std                              NaN                42.565391
#
#        arrival_delay_minutes    year  month         day  total_delay_minutes
# count             943.000000   943.0  943.0  943.000000           943.000000
# mean               36.757158  2025.0   12.0   25.323436            59.731707
# min                 0.000000  2025.0   12.0   21.000000             0.000000
# 25%                 0.000000  2025.0   12.0   23.000000             0.000000
# 50%                10.000000  2025.0   12.0   26.000000            12.000000
# 75%                61.500000  2025.0   12.0   28.000000            95.000000
# max               360.000000  2025.0   12.0   30.000000           540.000000
# std                52.517891     0.0    0.0    2.419479            86.926080

# %%
# Flight status distribution
if 'flight_status' in df_clean.columns:
    print("\nFlight Status Distribution:")
    print(df_clean['flight_status'].value_counts())
# Out:
# Flight Status Distribution:
# flight_status
# scheduled    385
# landed       242
# active       222
# Unknown       89
# unknown        2
# diverted       2
# cancelled      1
# Name: count, dtype: int64

# %%
# Display sample of cleaned data
print("\nSample of Cleaned Data:")
df_clean.head(10)
# Out:
# Sample of Cleaned Data:
#   flight_date flight_status departure_airport departure_iata  \
# 0  2025-12-23     scheduled          Carthage            TUN
# 1  2025-12-23     scheduled              Orly            ORY
# 2  2025-12-23     scheduled          Carthage            TUN
# 3  2025-12-23     scheduled          Heathrow            LHR
# 4  2025-12-23     scheduled              Orly            ORY
# 5  2025-12-23     scheduled          Carthage            TUN
# 6  2025-12-23     scheduled          Carthage            TUN
# 7  2025-12-23     scheduled         MÃ©rignac            BOD
# 8  2025-12-23     scheduled              Orly            ORY
# 9  2025-12-23     scheduled          Es Senia            ORN
#
#    departure_delay_minutes       departure_scheduled  \
# 0                      0.0 2025-12-23 20:05:00+00:00
# 1                      0.0 2025-12-23 19:15:00+00:00
# 2                      0.0 2025-12-23 18:25:00+00:00
# 3                      0.0 2025-12-23 16:50:00+00:00
# 4                      0.0 2025-12-23 13:00:00+00:00
# 5                      0.0 2025-12-23 17:00:00+00:00
# 6                      0.0 2025-12-23 16:55:00+00:00
# 7                      0.0 2025-12-23 16:35:00+00:00
# 8                      0.0 2025-12-23 17:00:00+00:00
# 9                      0.0 2025-12-23 15:40:00+00:00
#
#         departure_estimated departure_actual  \
# 0 2025-12-23 20:05:00+00:00              NaT
# 1 2025-12-23 19:15:00+00:00              NaT
# 2 2025-12-23 18:25:00+00:00              NaT
# 3 2025-12-23 16:50:00+00:00              NaT
# 4 2025-12-23 13:00:00+00:00              NaT
# 5 2025-12-23 17:00:00+00:00              NaT
# 6 2025-12-23 16:55:00+00:00              NaT
# 7 2025-12-23 16:35:00+00:00              NaT
# 8 2025-12-23 17:00:00+00:00              NaT
# 9 2025-12-23 15:40:00+00:00              NaT
#
#                            arrival_airport arrival_iata  ... arrival/actual  \
# 0             King Abdulaziz International          JED  ...            NaN
# 1                            Djerba-Zarzis          DJE  ...            NaN
# 2             King Abdulaziz International          JED  ...            NaN
# 3                                 Carthage          TUN  ...            NaN
# 4                                 Carthage          TUN  ...            NaN
# 5  Blaise Diagne International Airport\r\n          DSS  ...            NaN
# 6                                     Orly          ORY  ...            NaN
# 7                                 Carthage          TUN  ...            NaN
# 8                                 Carthage          TUN  ...            NaN
# 9                                 Carthage          TUN  ...            NaN
#
#    airline/name airline/iata airline/icao flight/number flight/iata  \
# 0           NaN          NaN          NaN           NaN         NaN
# 1           NaN          NaN          NaN           NaN         NaN
# 2           NaN          NaN          NaN           NaN         NaN
# 3           NaN          NaN          NaN           NaN         NaN
# 4           NaN          NaN          NaN           NaN         NaN
# 5           NaN          NaN          NaN           NaN         NaN
# 6           NaN          NaN          NaN           NaN         NaN
# 7           NaN          NaN          NaN           NaN         NaN
# 8           NaN          NaN          NaN           NaN         NaN
# 9           NaN          NaN          NaN           NaN         NaN
#
#   flight/icao day/of/week total/delay/minutes is/delayed
# 0         NaN         NaN                 NaN        NaN
# 1         NaN         NaN                 NaN        NaN
# 2         NaN         NaN                 NaN        NaN
# 3         NaN         NaN                 NaN        NaN
# 4         NaN         NaN                 NaN        NaN
# 5         NaN         NaN                 NaN        NaN
# 6         NaN         NaN                 NaN        NaN
# 7         NaN         NaN                 NaN        NaN
# 8         NaN         NaN                 NaN        NaN
# 9         NaN         NaN                 NaN        NaN
#
# [10 rows x 50 columns]

# %%
# Check df_clean columns
print("df_clean columns:")
print(list(df_clean.columns))
print(f"\nTotal columns: {len(df_clean.columns)}")
# Out:
# df_clean columns:
# ['flight_date', 'flight_status', 'departure_airport', 'departure_iata', 'departure_delay_minutes', 'departure_scheduled', 'departure_estimated', 'departure_actual', 'arrival_airport', 'arrival_iata', 'arrival_scheduled', 'arrival_delay_minutes', 'arrival_estimated', 'arrival_actual', 'airline_name', 'airline_iata', 'airline_icao', 'flight_number', 'flight_iata', 'flight_icao', 'year', 'month', 'day', 'day_of_week', 'total_delay_minutes', 'route', 'is_delayed', 'flight/date', 'flight/status', 'departure/airport', 'departure/iata', 'departure/delay/minutes', 'departure/scheduled', 'departure/estimated', 'departure/actual', 'arrival/airport', 'arrival/iata', 'arrival/scheduled', 'arrival/delay/minutes', 'arrival/estimated', 'arrival/actual', 'airline/name', 'airline/iata', 'airline/icao', 'flight/number', 'flight/iata', 'flight/icao', 'day/of/week', 'total/delay/minutes', 'is/delayed']
#
# Total columns: 50

# %% [markdown]
# ## Load and Merge Tunisair2022.csv

# %%
# Clean up df_clean - remove any columns with slashes from previous merge attempts
cols_to_keep = [col for col in df_clean.columns if '/' not in col]
df_clean = df_clean[cols_to_keep].copy()
print(f"Cleaned df_clean - removed slash columns. Now has {len(df_clean.columns)} columns")
print(f"Columns: {list(df_clean.columns)}")
# Out:
# Cleaned df_clean - removed slash columns. Now has 27 columns
# Columns: ['flight_date', 'flight_status', 'departure_airport', 'departure_iata', 'departure_delay_minutes', 'departure_scheduled', 'departure_estimated', 'departure_actual', 'arrival_airport', 'arrival_iata', 'arrival_scheduled', 'arrival_delay_minutes', 'arrival_estimated', 'arrival_actual', 'airline_name', 'airline_iata', 'airline_icao', 'flight_number', 'flight_iata', 'flight_icao', 'year', 'month', 'day', 'day_of_week', 'total_delay_minutes', 'route', 'is_delayed']

# %%
# Load Tunisair2022.csv
tunisair_2022_path = 'data/csv/Tunisair2022.csv'
df_2022 = pd.read_csv(tunisair_2022_path, encoding='utf-8')

print(f"Loaded Tunisair2022.csv: {len(df_2022)} records")
print(f"Original columns: {list(df_2022.columns)}")

# Rename columns to match df_clean format (replace / with _)
df_2022.columns = df_2022.columns.str.replace('/', '_')
print(f"\nRenamed columns: {list(df_2022.columns)}")

# Display the first few rows
print("\nFirst few rows:")
display(df_2022.head())

# Combine with existing clean data
print(f"\nBefore merge - df_clean: {len(df_clean)} records")
df_clean = pd.concat([df_clean, df_2022], ignore_index=True)
print(f"After merge - df_clean: {len(df_clean)} records")

# Remove any duplicates that might have been introduced
df_clean = df_clean.drop_duplicates()
print(f"After deduplication - df_clean: {len(df_clean)} records")

# Verify final columns
print(f"\nFinal column count: {len(df_clean.columns)}")
# Out:
# Loaded Tunisair2022.csv: 243 records
# Original columns: ['flight/date', 'flight/status', 'departure/airport', 'departure/iata', 'departure/delay/minutes', 'departure/scheduled', 'departure/estimated', 'departure/actual', 'arrival/airport', 'arrival/iata', 'arrival/scheduled', 'arrival/delay/minutes', 'arrival/estimated', 'arrival/actual', 'airline/name', 'airline/iata', 'airline/icao', 'flight/number', 'flight/iata', 'flight/icao', 'year', 'month', 'day', 'day/of/week', 'total/delay/minutes', 'route', 'is/delayed']
#
# Renamed columns: ['flight_date', 'flight_status', 'departure_airport', 'departure_iata', 'departure_delay_minutes', 'departure_scheduled', 'departure_estimated', 'departure_actual', 'arrival_airport', 'arrival_iata', 'arrival_scheduled', 'arrival_delay_minutes', 'arrival_estimated', 'arrival_actual', 'airline_name', 'airline_iata', 'airline_icao', 'flight_number', 'flight_iata', 'flight_icao', 'year', 'month', 'day', 'day_of_week', 'total_delay_minutes', 'route', 'is_delayed']
#
# First few rows:
#   flight_date flight_status departure_airport departure_iata  \
# 0  30/07/2022        landed          CARTHAGE            TUN
# 1  30/07/2022        landed          CARTHAGE            TUN
# 2  30/07/2022        landed     SAINT EXUPERY            LYS
# 3  30/07/2022        landed   GENEVE COINTRIN            GVA
# 4  30/07/2022        landed          STANSTED            STN
#
#    departure_delay_minutes departure_scheduled departure_estimated  \
# 0                     16.0    30/07/2022 15:35    30/07/2022 15:51
# 1                    120.0    30/07/2022 17:30                 NaN
# 2                      5.0    30/07/2022 17:30    30/07/2022 17:35
# 3                     90.0    30/07/2022 18:00    30/07/2022 19:30
# 4                     30.0    30/07/2022 17:50    30/07/2022 18:20
#
#    departure_actual arrival_airport arrival_iata  ... flight_number  \
# 0  30/07/2022 15:51            ORLY          ORY  ...           722
# 1               NaN      COTE DAZUR          NCE  ...           998
# 2  30/07/2022 17:35        CARTHAGE          TUN  ...           851
# 3  30/07/2022 19:30        CARTHAGE          TUN  ...           701
# 4  30/07/2022 18:20        CARTHAGE          TUN  ...           793
#
#    flight_iata flight_icao year month day day_of_week  total_delay_minutes  \
# 0        TU722      TAR722  NaN   NaN NaN         NaN                  NaN
# 1        TU998      TAR998  NaN   NaN NaN         NaN                  NaN
# 2        TU851      TAR851  NaN   NaN NaN         NaN                  NaN
# 3        TU701      TAR701  NaN   NaN NaN         NaN                  NaN
# 4        TU793      TAR793  NaN   NaN NaN         NaN                  NaN
#
#   route is_delayed
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN
#
# [5 rows x 27 columns]
# Before merge - df_clean: 1383 records
# After merge - df_clean: 1626 records
# After deduplication - df_clean: 1141 records
#
# Final column count: 27

# %% [markdown]
# ## 5. Load - Export Clean Dataset

# %%
# Export to CSV
output_file = 'data/csv/clean_tunisair_flights.csv'
df_clean.to_csv(output_file, index=False, encoding='utf-8')

print(f" Clean dataset exported to: {output_file}")
print(f"Records exported: {len(df_clean)}")
print(f"Columns exported: {len(df_clean.columns)}")
# Out:
# ✅ Clean dataset exported to: data/csv/clean_tunisair_flights.csv
# Records exported: 1141
# Columns exported: 27

# %% [markdown]
# ### Converting Tunisair_delay.db into CSV

# %%
import sqlite3
import pandas as pd
import os

# Export the first available table from the delay DB to CSV
# Adjust table selection if your DB uses a different table name

# Paths
_db_path = "data/db/tunisair_delay.db"
_db_export_path = "data/csv/tunisair_delay_export.csv"

os.makedirs("data/csv", exist_ok=True)

# Discover tables
conn = sqlite3.connect(_db_path)
_tables = pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';",
    conn,
)['name'].tolist()
print(f"Tables found in DB: {_tables}")

if not _tables:
    conn.close()
    raise RuntimeError("No tables found in the SQLite DB; cannot export.")

# Prefer a table named 'delays' if it exists, otherwise use the first table
_table_name = "delays" if "delays" in _tables else _tables[0]

df_delay = pd.read_sql_query(f"SELECT * FROM {_table_name};", conn)
conn.close()

df_delay.to_csv(_db_export_path, index=False, encoding="utf-8")
print(f"Exported table '{_table_name}' to {_db_export_path} with shape {df_delay.shape}")

# %%
# Filter tunisair_delay_export.csv by AIRLINE == 'TU' and export
import pandas as pd

input_file = 'data/csv/tunisair_delay_export.csv'
output_file = 'data/csv/tunisair_delay_export_TU.csv'

try:
    df = pd.read_csv(input_file, encoding='utf-8')
    if 'AIRLINE' not in df.columns:
        raise KeyError("Required column 'AIRLINE' not found in the CSV")

    df_tu = df[df['AIRLINE'] == 'TU']
    df_tu.to_csv(output_file, index=False, encoding='utf-8')

    print(f" Filtered TU records: {len(df_tu)} / {len(df)}")
    print(f" Saved filtered CSV to: {output_file}")
    print("\nPreview:")
    display(df_tu.head(10))
except Exception as e:
    print(f"Error filtering file '{input_file}': {e}")
# Out:
# ✅ Filtered TU records: 243 / 388
# 📄 Saved filtered CSV to: tunisair_delay_export_TU.csv
#
# Preview:
#                 ID_FLIGHT DEPARTURE_DATE ARRIVAL_DATE FLIGHT_NUMBER  \
# 0  TU722_30_07_2022_14_35     30/07/2022   30/07/2022         TU722
# 1  TU998_30_07_2022_16_30     30/07/2022   30/07/2022         TU998
# 2  TU851_30_07_2022_16_30     30/07/2022   30/07/2022         TU851
# 3  TU701_30_07_2022_17_00     30/07/2022   30/07/2022         TU701
# 4  TU793_30_07_2022_16_50     30/07/2022   30/07/2022         TU793
# 5  TU527_30_07_2022_18_55     30/07/2022   30/07/2022         TU527
# 6  TU999_30_07_2022_20_00     30/07/2022   30/07/2022         TU999
# 7  TU723_30_07_2022_19_30     30/07/2022   30/07/2022         TU723
# 8  TU203_30_07_2022_14_30     30/07/2022   30/07/2022         TU203
# 9  TU147_31_07_2022_07_45     31/07/2022   31/07/2022         TU147
#
#   FLIGHT_STATUS DEPARTURE_IATA            DEPARTURE_AIRPORT ARRIVAL_IATA  \
# 0        landed            TUN                     CARTHAGE          ORY
# 1        landed            TUN                     CARTHAGE          NCE
# 2        landed            LYS                SAINT EXUPERY          TUN
# 3        landed            GVA              GENEVE COINTRIN          TUN
# 4        landed            STN                     STANSTED          TUN
# 5        landed            DUS                   DUSSELDORF          TUN
# 6        landed            NCE                   COTE DAZUR          TUN
# 7        landed            ORY                         ORLY          TUN
# 8        active            YUL  PIERRE ELLIOTT TRUDEAU INTL          TUN
# 9        landed            DXB                   DUBAI INTL          TUN
#
#   ARRIVAL_AIRPORT DEPARTURE_SCHEDULED  ... ARRIVAL_HOUR DEPARTURE_ESTIMATED  \
# 0            ORLY    2022-07-30 15:35  ...          18h    2022-07-30 15:51
# 1      COTE DAZUR    2022-07-30 17:30  ...          21h                 NaN
# 2        CARTHAGE    2022-07-30 17:30  ...          17h    2022-07-30 17:35
# 3        CARTHAGE    2022-07-30 18:00  ...          19h    2022-07-30 19:30
# 4        CARTHAGE    2022-07-30 17:50  ...          20h    2022-07-30 18:20
# 5        CARTHAGE    2022-07-30 19:55  ...          20h                 NaN
# 6        CARTHAGE    2022-07-30 21:00  ...          20h                 NaN
# 7        CARTHAGE    2022-07-30 20:30  ...          20h    2022-07-30 20:29
# 8        CARTHAGE    2022-07-30 15:30  ...          03h    2022-07-30 15:43
# 9        CARTHAGE    2022-07-31 08:45  ...          10h                 NaN
#
#   ARRIVAL_ESTIMATED  DEPARTURE_ACTUAL    ARRIVAL_ACTUAL DEPARTURE_DELAY  \
# 0  2022-07-30 19:07  2022-07-30 15:51  2022-07-30 19:07            16.0
# 1  2022-07-30 22:00               NaN  2022-07-30 22:00           120.0
# 2  2022-07-30 18:25  2022-07-30 17:35  2022-07-30 18:25             5.0
# 3  2022-07-30 20:15  2022-07-30 19:30  2022-07-30 20:15            90.0
# 4  2022-07-30 21:16  2022-07-30 18:20  2022-07-30 21:16            30.0
# 5               NaN               NaN               NaN             NaN
# 6               NaN               NaN               NaN             NaN
# 7  2022-07-30 21:45  2022-07-30 20:29  2022-07-30 21:45             NaN
# 8               NaN  2022-07-30 15:43               NaN            13.0
# 9  2022-07-31 11:24               NaN  2022-07-31 11:24             0.0
#
#   ARRIVAL_DELAY  AIRLINE  ARRIVAL_COUNTRY     DEPARTURE_COUNTRY
# 0           7.0       TU           FRANCE               TUNISIA
# 1         120.0       TU           FRANCE               TUNISIA
# 2           5.0       TU          TUNISIA                FRANCE
# 3          80.0       TU          TUNISIA           SWITZERLAND
# 4          21.0       TU          TUNISIA        UNITED KINGDOM
# 5           NaN       TU          TUNISIA               GERMANY
# 6           NaN       TU          TUNISIA                FRANCE
# 7          10.0       TU          TUNISIA                FRANCE
# 8           NaN       TU          TUNISIA                CANADA
# 9          31.0       TU          TUNISIA  UNITED ARAB EMIRATES
#
# [10 rows x 22 columns]
